# %% [markdown]
# # Case study on bollywood movie dataset

# %% [markdown]
# Meta-Data of the Bollywood Dataset:
#
# SINo - Identifier for the movies.
# Release Date - Date on which the movie was released.
# MovieName - Name of the movie.
# ReleaseTime - Mentions special time of release. LW (Long weekend), FS (Festive Season), HS (Holiday Season), N (Normal).
# Genre – Genre of the film such as Romance, Thriller, Action, Comedy, etc
# Budget – Movie creation budget
# BoxOfficeCollection – Box office collection
# YoutubeViews – Number of views of the YouTube trailers
# YoutubeLikes – Number of likes of the YouTube trailers
# YoutubeDislikes – Number of dislikes of the YouTube trailers

# %%
import pandas as pd
movie_data=pd.read_csv("bollywood.csv")
movie_data
# Out:
#      SlNo ReleaseDate                  MovieName ReleaseTime     Genre  \
# 0       1   18-Apr-14                    2States          LW   Romance
# 1       2    4-Jan-13                 TableNo.21           N  Thriller
# 2       3   18-Jul-14            AmitSahniKiList           N    Comedy
# 3       4    4-Jan-13            RajdhaniExpress           N     Drama
# 4       5    4-Jul-14                BobbyJasoos           N    Comedy
# ..    ...         ...                        ...         ...       ...
# 144   145   27-Feb-15            DumLagaKeHaisha           N    Comedy
# 145   146   13-Mar-15                       NH10           N  Thriller
# 146   147   20-Mar-15  DilliwaliZaalimGirlfriend           N    Comedy
# 147   148   20-Mar-15                   Hunterrr           N    Comedy
# 148   149   23-May-14              Kochadaiiyaan          HS    Action
#
#      Budget  BoxOfficeCollection  YoutubeViews  YoutubeLikes  YoutubeDislikes
# ...

# %%
movie_data.columns
# Out:
# Index(['SlNo', 'ReleaseDate', 'MovieName', 'ReleaseTime', 'Genre', 'Budget',
#        'BoxOfficeCollection', 'YoutubeViews', 'YoutubeLikes',
#        'YoutubeDislikes'],
#       dtype='object')

# %%
movie_data.shape
# Out:
# (149, 10)

# %%
movie_data.head()
# Out:
#    SlNo ReleaseDate        MovieName ReleaseTime     Genre  Budget  \
# 0     1   18-Apr-14          2States          LW   Romance      36
# 1     2    4-Jan-13       TableNo.21           N  Thriller      10
# 2     3   18-Jul-14  AmitSahniKiList           N    Comedy      10
# 3     4    4-Jan-13  RajdhaniExpress           N     Drama       7
# 4     5    4-Jul-14      BobbyJasoos           N    Comedy      18
#
#    BoxOfficeCollection  YoutubeViews  YoutubeLikes  YoutubeDislikes
# 0               104.00       8576361         26622             2527
# 1                12.00       1087320          1129              137
# 2                 4.00        572336           586               54
# 3                 0.35         42626            86               19
# 4                10.80       3113427          4512             1224

# %%
movie_data.head(15)
# Out:
#     SlNo ReleaseDate               MovieName ReleaseTime     Genre  Budget  \
# 0      1   18-Apr-14                 2States          LW   Romance      36
# 1      2    4-Jan-13              TableNo.21           N  Thriller      10
# 2      3   18-Jul-14         AmitSahniKiList           N    Comedy      10
# 3      4    4-Jan-13         RajdhaniExpress           N     Drama       7
# 4      5    4-Jul-14             BobbyJasoos           N    Comedy      18
# 5      6   30-May-14              Citylights          HS     Drama       7
# 6      7   19-Sep-14           Daawat-E-Ishq           N    Comedy      30
# 7      8   11-Jan-13  MatruKiBijleeKaMandola           N    Comedy      33
# 8      9   10-Jan-14             DedhIshqiya          LW    Comedy      31
# 9     10   11-Jan-13               Gangoobai           N     Drama       2
# 10    11   28-Mar-14             Dishkiyaoon           N    Action      28
# ...

# %%
movie_data.tail()
# Out:
#      SlNo ReleaseDate                  MovieName ReleaseTime     Genre  \
# 144   145   27-Feb-15            DumLagaKeHaisha           N    Comedy
# 145   146   13-Mar-15                       NH10           N  Thriller
# 146   147   20-Mar-15  DilliwaliZaalimGirlfriend           N    Comedy
# 147   148   20-Mar-15                   Hunterrr           N    Comedy
# 148   149   23-May-14              Kochadaiiyaan          HS    Action
#
#      Budget  BoxOfficeCollection  YoutubeViews  YoutubeLikes  YoutubeDislikes
# 144      15                30.00       3250917          8185              615
# 145      13                32.10       5592977         15464             1513
# 146      32                12.00       2316047          4289              807
# 147       5                11.89       4674795          3706              762
# 148     150               120.00       4740727         13466             2649

# %%
movie_data.tail(20)
# Out:
#      SlNo ReleaseDate                  MovieName ReleaseTime     Genre  \
# 129   130   25-Oct-13                MickeyVirus           N    Comedy
# 130   131    6-Sep-13                    Zanjeer          LW    Action
# 131   132    6-Sep-13          ShuddhDesiRomance          LW   Romance
# 132   133   13-Sep-13                 GrandMasti          LW    Comedy
# 133   134   16-May-14              ChildrenOfWar          HS     Drama
# 134   135   20-Sep-13       PhataPosterNiklaHero           N     Drama
# 135   136   20-Sep-13                TheLunchbox           N     Drama
# 136   137    9-Jan-15                      Tevar           N    Action
# 137   138   16-Jan-15                      Alone           N  Thriller
# 138   139   23-Jan-15                       Baby           N    Action
# 139   140   30-Jan-15                 Hawaizaada           N     Drama
# 140   141   30-Jan-15                Khamoshiyan           N  Thriller
# ...

# %%
movie_data.sample()
# Out:
#      SlNo ReleaseDate    MovieName ReleaseTime  Genre  Budget  \
# 135   136   20-Sep-13  TheLunchbox           N  Drama      10
#
#      BoxOfficeCollection  YoutubeViews  YoutubeLikes  YoutubeDislikes
# 135                 85.0       1064854          4054              285

# %%
movie_data.sample(20)
# Out:
#      SlNo ReleaseDate        MovieName ReleaseTime     Genre  Budget  \
# 108   109   21-Feb-14     Darr@TheMall           N  Thriller      15
# 145   146   13-Mar-15             NH10           N  Thriller      13
# 86     87   28-Mar-14      Youngistaan           N     Drama      26
# 0       1   18-Apr-14          2States          LW   Romance      36
# 109   110   26-Jul-13            Issaq           N   Romance      10
# 72     73   10-May-13        GoGoaGone           N    Comedy      16
# 32     33   23-May-14        Heropanti          HS   Romance      21
# 91     92    5-Dec-14    ActionJackson           N    Action      90
# 26     27   24-Oct-14     HappyNewYear          LW     Drama     125
# 139   140   30-Jan-15       Hawaizaada           N     Drama      25
# 59     60   12-Apr-13    NautankiSaala          LW    Comedy       9
# 36     37    6-Jun-14          Holiday          HS    Action      50
# 14     15    8-Aug-14    Entertainment           N    Comedy      60
# ...

# %%
movie_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   SlNo                 149 non-null    int64
#  1   ReleaseDate          149 non-null    object
#  2   MovieName            149 non-null    object
#  3   ReleaseTime          149 non-null    object
#  4   Genre                149 non-null    object
#  5   Budget               149 non-null    int64
#  6   BoxOfficeCollection  149 non-null    float64
#  7   YoutubeViews         149 non-null    int64
#  8   YoutubeLikes         149 non-null    int64
#  9   YoutubeDislikes      149 non-null    int64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 11.8+ KB

# %%
movie_data.isnull().sum()
# Out:
# SlNo                   0
# ReleaseDate            0
# MovieName              0
# ReleaseTime            0
# Genre                  0
# Budget                 0
# BoxOfficeCollection    0
# YoutubeViews           0
# YoutubeLikes           0
# YoutubeDislikes        0
# dtype: int64

# %%
movie_data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Q1. How many records are present in the dataset?

# %%
movie_data.shape
# Out:
# (149, 10)

# %%
print("Total no of records in a dataset",movie_data.shape[0])
# Out:
# Total no of records in a dataset 149

# %% [markdown]
# ### we use the shape attribute of a Pandas dataframe and check the number of rows by using index 0.

# %% [markdown]
# ### Q2. How many movies were released in each Release Time? Sort number of releases in Release Time in descending order.

# %%
movie_data['ReleaseTime']
# Out:
# 0      LW
# 1       N
# 2       N
# 3       N
# 4       N
#        ..
# 144     N
# 145     N
# 146     N
# 147     N
# 148    HS
# Name: ReleaseTime, Length: 149, dtype: object

# %%
movie_data['ReleaseTime'].value_counts()
# Out:
# N     99
# HS    18
# FS    17
# LW    15
# Name: ReleaseTime, dtype: int64

# %% [markdown]
# ### The highest number of movies were released on a normal time, followed by the holiday season, the festive season, and then the long weekend having the lowest number of releases.

# %% [markdown]
# ### Q3. Which genre had highest number of releases during the Festive Season?

# %%
movie_data[['ReleaseTime','Genre']]
# Out:
#     ReleaseTime     Genre
# 0            LW   Romance
# 1             N  Thriller
# 2             N    Comedy
# 3             N     Drama
# 4             N    Comedy
# ..          ...       ...
# 144           N    Comedy
# 145           N  Thriller
# 146           N    Comedy
# 147           N    Comedy
# 148          HS    Action
#
# [149 rows x 2 columns]

# %%
movie_data[movie_data['ReleaseTime']=='FS'].Genre.value_counts()
# Out:
# Drama       4
# Thriller    4
# Action      3
# Romance     3
# Comedy      3
# Name: Genre, dtype: int64

# %% [markdown]
# ### The genres Thriller and Drama had the highest number of releases during the Festive Season, having 4 released each.

# %% [markdown]
# ### Q.4 How many movies in each genre got released in different release times like long weekend, festive season, etc.

# %%
pd.crosstab(movie_data.ReleaseTime,movie_data.Genre)
# Out:
# Genre        Action  Comedy  Drama  Romance  Thriller
# ReleaseTime
# FS                3       3      4        3         4
# HS                3       5      6        3         1
# LW                3       5      1        4         2
# N                15      23     24       15        22

# %% [markdown]
# ### Q.5 In which year were maximum number movie released?

# %%
movie_data.sample(5)
# Out:
#      SlNo ReleaseDate    MovieName ReleaseTime     Genre  Budget  \
# 32     33   23-May-14    Heropanti          HS   Romance      21
# 28     29   18-Jul-14   HateStory2           N  Thriller      12
# 124   125   29-Nov-13  BullettRaja           N    Comedy      50
# 90     91   21-Jun-13   Raanjhanaa           N   Romance      35
# 34     35   21-Feb-14      Highway           N     Drama      30
#
#      BoxOfficeCollection  YoutubeViews  YoutubeLikes  YoutubeDislikes
# 32                 65.00       4005695          8189             1814
# 28                 27.16      13798789         15708             5226
# 124                40.00       4015674          8084             2129
# 90                100.00       5470632         12413             1018
# 34                 27.25       3043012          9100              971

# %%
movie_data['ReleaseDate']
# Out:
# 0      18-Apr-14
# 1       4-Jan-13
# 2      18-Jul-14
# 3       4-Jan-13
# 4       4-Jul-14
#          ...
# 144    27-Feb-15
# 145    13-Mar-15
# 146    20-Mar-15
# 147    20-Mar-15
# 148    23-May-14
# Name: ReleaseDate, Length: 149, dtype: object

# %%
pd.to_datetime('23-May-14').day
# Out:
# 23

# %%
#convert releasedate into datetime data type of pandas library
movie_data['year']=pd.to_datetime(movie_data['ReleaseDate']).dt.year
movie_data['year']
# Out:
# 0      2014
# 1      2013
# 2      2014
# 3      2013
# 4      2014
#        ...
# 144    2015
# 145    2015
# 146    2015
# 147    2015
# 148    2014
# Name: year, Length: 149, dtype: int64

# %%
movie_data.columns
# Out:
# Index(['SlNo', 'ReleaseDate', 'MovieName', 'ReleaseTime', 'Genre', 'Budget',
#        'BoxOfficeCollection', 'YoutubeViews', 'YoutubeLikes',
#        'YoutubeDislikes', 'year'],
#       dtype='object')

# %%
movie_data['year'].value_counts()
# Out:
# 2014    70
# 2013    67
# 2015    12
# Name: year, dtype: int64

# %% [markdown]
# ### Q.6 Which month of the year typically sees most releases of high budgeted movies, that is, movies with budget                of 30 crore or more?

# %%
new_data=movie_data[movie_data['Budget']>=30]
new_data
# Out:
#      SlNo ReleaseDate                       MovieName ReleaseTime     Genre  \
# 0       1   18-Apr-14                         2States          LW   Romance
# 6       7   19-Sep-14                   Daawat-E-Ishq           N    Comedy
# 7       8   11-Jan-13          MatruKiBijleeKaMandola           N    Comedy
# 8       9   10-Jan-14                     DedhIshqiya          LW    Comedy
# 12     13   27-Jun-14                       EkVillain          HS   Romance
# 14     15    8-Aug-14                   Entertainment           N    Comedy
# 16     17   25-Jan-13                           Race2          LW  Thriller
# 22     23   14-Feb-14                          Gunday           N    Action
# 24     25   21-Nov-14                     HappyEnding           N   Romance
# 25     26    8-Feb-13                       Special26           N     Drama
# 26     27   24-Oct-14                    HappyNewYear          LW     Drama
# ...

# %%
new_data.shape[0]
# Out:
# 56

# %%
new_data
# Out:
#      SlNo ReleaseDate                       MovieName ReleaseTime     Genre  \
# 0       1   18-Apr-14                         2States          LW   Romance
# 6       7   19-Sep-14                   Daawat-E-Ishq           N    Comedy
# 7       8   11-Jan-13          MatruKiBijleeKaMandola           N    Comedy
# 8       9   10-Jan-14                     DedhIshqiya          LW    Comedy
# 12     13   27-Jun-14                       EkVillain          HS   Romance
# 14     15    8-Aug-14                   Entertainment           N    Comedy
# 16     17   25-Jan-13                           Race2          LW  Thriller
# 22     23   14-Feb-14                          Gunday           N    Action
# 24     25   21-Nov-14                     HappyEnding           N   Romance
# 25     26    8-Feb-13                       Special26           N     Drama
# 26     27   24-Oct-14                    HappyNewYear          LW     Drama
# ...

# %%
new_data['month']=pd.to_datetime(new_data['ReleaseDate']).dt.month
new_data.columns
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11952\1836953530.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data['month']=pd.to_datetime(new_data['ReleaseDate']).dt.month
# Index(['SlNo', 'ReleaseDate', 'MovieName', 'ReleaseTime', 'Genre', 'Budget',
#        'BoxOfficeCollection', 'YoutubeViews', 'YoutubeLikes',
#        'YoutubeDislikes', 'year', 'month'],
#       dtype='object')

# %%
new_data['month'].value_counts()
# Out:
# 2     8
# 8     7
# 1     6
# 11    6
# 6     5
# 7     5
# 9     4
# 10    4
# 4     3
# 3     3
# 5     3
# 12    2
# Name: month, dtype: int64

# %% [markdown]
# ### The month 2 - February typically sees most releases of high budgeted movies.

# %% [markdown]
# ### Q.7 Which are the top 10 flop movies with minimum return on investment (ROI)?

# %%
movie_data.columns
# Out:
# Index(['SlNo', 'ReleaseDate', 'MovieName', 'ReleaseTime', 'Genre', 'Budget',
#        'BoxOfficeCollection', 'YoutubeViews', 'YoutubeLikes',
#        'YoutubeDislikes', 'year'],
#       dtype='object')

# %%
#ROI(Return on investment)
movie_data['ROI']=movie_data['BoxOfficeCollection']/movie_data['Budget']*100
movie_data['ROI']
# Out:
# 0      288.888889
# 1      120.000000
# 2       40.000000
# 3        5.000000
# 4       60.000000
#           ...
# 144    200.000000
# 145    246.923077
# 146     37.500000
# 147    237.800000
# 148     80.000000
# Name: ROI, Length: 149, dtype: float64

# %%
movie_data.sort_values(by='ROI')
# Out:
#      SlNo ReleaseDate          MovieName ReleaseTime     Genre  Budget  \
# 9      10   11-Jan-13          Gangoobai           N     Drama       2
# 15     16   18-Jan-13            Bandook           N    Action       4
# 53     54   22-Mar-13            SonaSpa           N  Thriller      10
# 3       4    4-Jan-13    RajdhaniExpress           N     Drama       7
# 49     50    2-May-14  KyaDilliKyaLahore          HS     Drama       7
# ..    ...         ...                ...         ...       ...     ...
# 87     88   14-Jun-13             Fukrey           N    Comedy       5
# 135   136   20-Sep-13        TheLunchbox           N     Drama      10
# 132   133   13-Sep-13         GrandMasti          LW    Comedy      35
# 89     90   19-Dec-14                 PK          HS     Drama      85
# 64     65   26-Apr-13          Aashiqui2           N   Romance      12
#
#      BoxOfficeCollection  YoutubeViews  YoutubeLikes  YoutubeDislikes  year  \
# ...

# %%
movie_data.sort_values(by='ROI').MovieName[:10]
# Out:
# 9              Gangoobai
# 15               Bandook
# 53               SonaSpa
# 3        RajdhaniExpress
# 49     KyaDilliKyaLahore
# 121               Satya2
# 67           PuraniJeans
# 103         SamratandCo.
# 30             Heartless
# 102              Kaanchi
# Name: MovieName, dtype: object

# %%
movie_data.sort_values(by='ROI',ascending=False).MovieName[:10]
# Out:
# 64                  Aashiqui2
# 89                         PK
# 132                GrandMasti
# 135               TheLunchbox
# 87                     Fukrey
# 58                    MaryKom
# 128                    Shahid
# 37     HumptySharmaKiDulhania
# 101          BhaagMilkhaBhaag
# 115            ChennaiExpress
# Name: MovieName, dtype: object

# %%
ROI_df=movie_data.sort_values(by='ROI',ascending=False)
ROI_df[['MovieName','ROI']].tail(10)
# Out:
#              MovieName        ROI
# 102            Kaanchi  12.903226
# 30           Heartless  12.500000
# 103       SamratandCo.  11.111111
# 67         PuraniJeans  11.000000
# 121             Satya2   7.333333
# 49   KyaDilliKyaLahore   7.142857
# 3      RajdhaniExpress   5.000000
# 53             SonaSpa   2.400000
# 15             Bandook   2.250000
# 9            Gangoobai   0.500000

# %% [markdown]
# ### Q.8 Do the movies have higher ROI if they get released on festive seasons or long weekend?Calculate the average ROI for different release times.

# %%
movie_data.columns
# Out:
# Index(['SlNo', 'ReleaseDate', 'MovieName', 'ReleaseTime', 'Genre', 'Budget',
#        'BoxOfficeCollection', 'YoutubeViews', 'YoutubeLikes',
#        'YoutubeDislikes', 'year', 'ROI'],
#       dtype='object')

# %%
movie_data['ReleaseTime'].unique()
# Out:
# array(['LW', 'N', 'HS', 'FS'], dtype=object)

# %%
g1=movie_data.groupby('ReleaseTime')
print(g1)
g1.get_group('LW')
# Out:
# ...
#      SlNo ReleaseDate             MovieName ReleaseTime     Genre  Budget  \
# 0       1   18-Apr-14               2States          LW   Romance      36
# 8       9   10-Jan-14           DedhIshqiya          LW    Comedy      31
# 16     17   25-Jan-13                 Race2          LW  Thriller      60
# 26     27   24-Oct-14          HappyNewYear          LW     Drama     125
# 52     53    4-Apr-14          MainTeraHero          LW    Comedy      40
# 59     60   12-Apr-13         NautankiSaala          LW    Comedy       9
# 61     62   12-Apr-13  Commando-AOneManArmy          LW    Action      22
# 78     79   15-Aug-14        SinghamReturns          LW    Action      90
# 80     81   24-May-13          IshkqinParis          LW   Romance      15
# 83     84   10-Jan-14              Yaariyan          LW   Romance      19
# 96     97    2-Oct-13              Besharam          LW    Comedy      85
# 114   115   11-Apr-14      BhootnathReturns          LW  Thriller      29
# ...

# %%
movie_data.groupby('ReleaseTime').ROI.mean()
# Out:
# ReleaseTime
# FS    197.385320
# HS    185.086678
# LW    212.720531
# N     165.772163
# Name: ROI, dtype: float64

# %% [markdown]
# ### Movies which release on the long weekend and festive seasons have higher values of ROI 212 and 197 respectively.

# %% [markdown]
# ### Q9. Is there a correlation between box office collection and YouTube likes? Is the correlation positive or negative.

# %%
movie_data.corr(numeric_only=True)
# Out:
#                          SlNo    Budget  BoxOfficeCollection  YoutubeViews  \
# SlNo                 1.000000  0.116899             0.036908      0.025027
# Budget               0.116899  1.000000             0.650401      0.589038
# BoxOfficeCollection  0.036908  0.650401             1.000000      0.588632
# YoutubeViews         0.025027  0.589038             0.588632      1.000000
# YoutubeLikes         0.018163  0.608916             0.682517      0.884055
# YoutubeDislikes      0.035949  0.665343             0.623941      0.846739
# year                 0.132755  0.062069             0.011673      0.280666
# ROI                  0.037314  0.072050             0.585042      0.252847
#
#                      YoutubeLikes  YoutubeDislikes      year       ROI
# SlNo                     0.018163         0.035949  0.132755  0.037314
# Budget                   0.608916         0.665343  0.062069  0.072050
# BoxOfficeCollection      0.682517         0.623941  0.011673  0.585042
# ...

# %%
movie_data[['BoxOfficeCollection','YoutubeLikes']].corr()
# Out:
#                      BoxOfficeCollection  YoutubeLikes
# BoxOfficeCollection             1.000000      0.682517
# YoutubeLikes                    0.682517      1.000000

# %% [markdown]
# ### The columns BoxOfficeCollection and YoutubeLikes have a moderate degree of positive linear correlation, having correlation coefficient 0.68. This means that if BoxOfficeCollection increases by 100%, the YoutubeLikes also increase by 68%.

# %% [markdown]
# ### Q.10 Which of the variables among Budget, BoxOfficeCollection, YoutubeView, YoutubeLikes, YoutubeDislikes are highly correlated?

# %%
movie_data.columns
# Out:
# Index(['SlNo', 'ReleaseDate', 'MovieName', 'ReleaseTime', 'Genre', 'Budget',
#        'BoxOfficeCollection', 'YoutubeViews', 'YoutubeLikes',
#        'YoutubeDislikes', 'year', 'ROI'],
#       dtype='object')

# %%
movie_data[['Budget',
       'BoxOfficeCollection', 'YoutubeViews', 'YoutubeLikes',
       'YoutubeDislikes']].corr()
# Out:
#                        Budget  BoxOfficeCollection  YoutubeViews  \
# Budget               1.000000             0.650401      0.589038
# BoxOfficeCollection  0.650401             1.000000      0.588632
# YoutubeViews         0.589038             0.588632      1.000000
# YoutubeLikes         0.608916             0.682517      0.884055
# YoutubeDislikes      0.665343             0.623941      0.846739
#
#                      YoutubeLikes  YoutubeDislikes
# Budget                   0.608916         0.665343
# BoxOfficeCollection      0.682517         0.623941
# YoutubeViews             0.884055         0.846739
# YoutubeLikes             1.000000         0.859730
# YoutubeDislikes          0.859730         1.000000

# %%
import seaborn as sns
c=movie_data[['Budget',
       'BoxOfficeCollection', 'YoutubeViews', 'YoutubeLikes',
       'YoutubeDislikes']].corr()
sns.heatmap(c,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### Q.11 During 2013−2015 period, highlight the genre of movies and their box office collection? Visualize with best fit graph.

# %%
import seaborn as sns
sns.barplot(x='year',y='BoxOfficeCollection',data=movie_data,hue='Genre')
# Out:
# <AxesSubplot:xlabel='year', ylabel='BoxOfficeCollection'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.barplot(x='year',y='YoutubeLikes',data=movie_data,hue='year')
plt.grid()

# %%
movie_data['year'].value_counts()
# Out:
# 2014    70
# 2013    67
# 2015    12
# Name: year, dtype: int64

# %%
movie_data.columns
# Out:
# Index(['SlNo', 'ReleaseDate', 'MovieName', 'ReleaseTime', 'Genre', 'Budget',
#        'BoxOfficeCollection', 'YoutubeViews', 'YoutubeLikes',
#        'YoutubeDislikes', 'year', 'ROI'],
#       dtype='object')

# %%
movie_data[['year','YoutubeLikes','MovieName']].max()
# Out:
# year                      2015
# YoutubeLikes            101275
# MovieName       ZillaGhaziabad
# dtype: object

# %%
you_tube_max=movie_data.groupby('year').YoutubeLikes.max()

# %%
movie_data.to_csv('movie_new.csv')

# %%
you_tube_max
# Out:
# year
# 2013     72070
# 2014    101275
# 2015     29246
# Name: YoutubeLikes, dtype: int64
